# %% [markdown]
# d-sandbox
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 400px">
# </div>

# %% [markdown]
# # Streaming Query
# 1. Build streaming DataFrames
# 1. Display streaming query results
# 1. Write streaming query results
# 1. Monitor streaming query
#
# ##### Classes
# - DataStreamReader (<a href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=datastreamreader#pyspark.sql.streaming.DataStreamReader" target="_blank">Python</a>/<a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/streaming/DataStreamReader.html" target="_blank">Scala</a>)
# - DataStreamWriter (<a href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=datastreamwriter#pyspark.sql.streaming.DataStreamWriter" target="_blank">Python</a>/<a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/streaming/DataStreamWriter.html" target="_blank">Scala</a>)
# - StreamingQuery (<a href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=streamingquery#pyspark.sql.streaming.StreamingQuery" target="_blank">Python</a>/<a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/streaming/StreamingQuery.html" target="_blank">Scala</a>)

# %%
# %run ./Includes/Classroom-Setup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Datasets mounted and student environment set up

# %%
schema = "device STRING, ecommerce STRUCT<purchase_revenue_in_usd: DOUBLE, total_item_quantity: BIGINT, unique_items: BIGINT>, event_name STRING, event_previous_timestamp BIGINT, event_timestamp BIGINT, geo STRUCT<city: STRING, state: STRING>, items ARRAY<STRUCT<coupon: STRING, item_id: STRING, item_name: STRING, item_revenue_in_usd: DOUBLE, price_in_usd: DOUBLE, quantity: BIGINT>>, traffic_source STRING, user_first_touch_timestamp BIGINT, user_id STRING"

df = (spark.readStream
  .schema(schema)
  .option("maxFilesPerTrigger", 1)
  .parquet(eventsPath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Build streaming DataFrames

# %%
df.isStreaming
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: True</div>

# %%
from pyspark.sql.functions import col, approx_count_distinct, count

emailTrafficDF = (df.filter(col("traffic_source") == "email")
  .withColumn("mobile", col("device").isin(["iOS", "Android"]))
  .select("user_id", "event_timestamp", "mobile")
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Write streaming query results

# %%
userhome
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: &#39;dbfs:/user/abdulhakeemadefioye@gmail.com&#39;</div>

# %%
checkpointPath = userhome + "/email_traffic/checkpoint"
outputPath = userhome + "/email_traffic/output"

devicesQuery = (emailTrafficDF.writeStream
  .outputMode("append")
  .format("parquet")
  .queryName("email_traffic_p")
  .trigger(processingTime="1 second")
  .option("checkpointLocation", checkpointPath)
  .start(outputPath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Monitor streaming query

# %%
devicesQuery.id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: &#39;4f83f7f9-b315-4405-b566-d1ad0fc97619&#39;</div>

# %%
devicesQuery.status
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: {&#39;message&#39;: &#39;Waiting for next trigger&#39;,
#  &#39;isDataAvailable&#39;: False,
#  &#39;isTriggerActive&#39;: False}</div>

# %%
devicesQuery.awaitTermination(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: False</div>

# %%
devicesQuery.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Coupon Sales Lab
# Process and append streaming data on transactions using coupons.
# 1. Read data stream
# 2. Filter for transactions with coupons codes
# 3. Write streaming query results to parquet
# 4. Monitor streaming query
# 5. Stop streaming query
#
# ##### Classes
# - [DataStreamReader](http://spark.apache.org/docs/3.0.0/api/scala/org/apache/spark/sql/streaming/DataStreamReader.html)
# - [DataStreamWriter](http://spark.apache.org/docs/3.0.0/api/scala/org/apache/spark/sql/streaming/DataStreamWriter.html)
# - [StreamingQuery](http://spark.apache.org/docs/3.0.0/api/scala/org/apache/spark/sql/streaming/StreamingQuery.html)

# %%
schema = "order_id BIGINT, email STRING, transaction_timestamp BIGINT, total_item_quantity BIGINT, purchase_revenue_in_usd DOUBLE, unique_items BIGINT, items ARRAY<STRUCT<coupon: STRING, item_id: STRING, item_name: STRING, item_revenue_in_usd: DOUBLE, price_in_usd: DOUBLE, quantity: BIGINT>>"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### 1. Read data stream
# - Use schema stored in **`schema`**
# - Set to process 1 file per trigger
# - Read from parquet with filepath stored in **`salesPath`**
#
# Assign the resulting DataFrame to **`df`**

# %%
df = (spark
      .readStream
      .schema(schema)
      .option("maxFilesPerTrigger", 1)
      .parquet(salesPath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.isStreaming
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: True</div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: [&#39;order_id&#39;,
#  &#39;email&#39;,
#  &#39;transaction_timestamp&#39;,
#  &#39;total_item_quantity&#39;,
#  &#39;purchase_revenue_in_usd&#39;,
#  &#39;unique_items&#39;,
#  &#39;items&#39;]</div>

# %% [markdown]
# -sandbox
# ##### <img alt="Best Practice" title="Best Practice" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-blue-ribbon.svg"/> Check your work

# %%
assert df.isStreaming
assert df.columns == ['order_id', 'email', 'transaction_timestamp', 'total_item_quantity', 'purchase_revenue_in_usd', 'unique_items', 'items']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### 2. Filter for transactions with coupon codes
# - Explode **`items`** field in **`df`**
# - Filter for records where **`items.coupon`** is not null
#
# Assign the resulting DataFrame to **`couponSalesDF`**.

# %%
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
couponSalesDF = (df
                 .withColumn("items", explode(col("items")))
                 .filter(col("items.coupon").isNotNull())
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
# ##### <img alt="Best Practice" title="Best Practice" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-blue-ribbon.svg"/> Check your work

# %%
schemaStr = str(couponSalesDF.schema)
assert "StructField(items,StructType(List(StructField(coupon" in schemaStr, "items column was not exploded"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### 3. Write streaming query results to parquet
# - Configure streaming query to write out to parquet in "append" mode
# - Set query name to "coupon_sales"
# - Set a trigger interval of 1 second
# - Set checkpoint location to **`couponsCheckpointPath`**
# - Set output filepath to **`couponsOutputPath`**
#
# Assign the resulting streaming query to **`couponSalesQuery`**.

# %%
couponsCheckpointPath = workingDir + "/coupon-sales/checkpoint"
couponsOutputPath = workingDir + "/coupon-sales/output"

couponSalesQuery = (couponSalesDF
                    .writeStream
                    .outputMode("append")
                    .format("parquet")
                    .queryName("coupon_sales")
                    .trigger(processingTime="1 second")
                    .option("checkpointLocation", couponsCheckpointPath)
                    .start(couponsOutputPath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
# ##### <img alt="Best Practice" title="Best Practice" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-blue-ribbon.svg"/> Check your work

# %%
untilStreamIsReady("coupon_sales")
assert couponSalesQuery.isActive
assert len(dbutils.fs.ls(couponsOutputPath)) > 0
assert len(dbutils.fs.ls(couponsCheckpointPath)) > 0
assert "coupon_sales" in couponSalesQuery.lastProgress["name"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3125459117137434&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>untilStreamIsReady<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;coupon_sales&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> <span class="ansi-green-fg">assert</span> couponSalesQuery<span class="ansi-blue-fg">.</span>isActive
# <span class="ansi-green-intense-fg ansi-bold">      3</span> <span class="ansi-green-fg">assert</span> len<span class="ansi-blue-fg">(</span>dbutils<span class="ansi-blue-fg">.</span>fs<span class="ansi-blue-fg">.</span>ls<span class="ansi-blue-fg">(</span>couponsOutputPath<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span> <span class="ansi-blue-fg">&gt;</span> <span class="ansi-cyan-fg">0</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> <span class="ansi-green-fg">assert</span> len<span class="ansi-blue-fg">(</span>dbutils<span class="ansi-blue-fg">.</span>fs<span class="ansi-blue-fg">.</span>ls<span class="ansi-blue-fg">(</span>couponsCheckpointPath<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span> <span class="ansi-blue-fg">&gt;</span> <span class="ansi-cyan-fg">0</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span> <span class="ansi-green-fg">assert</span> <span class="ansi-blue-fg">&#34;coupon_sales&#34;</span> <span class="ansi-green-fg">in</span> couponSalesQuery<span class="ansi-blue-fg">.</span>lastProgress<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#34;name&#34;</span><span class="ansi-blue-fg">]</span>
#
# <span class="ansi-green-fg">&lt;command-3125459117136491&gt;</span> in <span class="ansi-cyan-fg">untilStreamIsReady</span><span class="ansi-blue-fg">(name, progressions)</span>
# <span class="ansi-green-intense-fg ansi-bold">     99</span> <span class="ansi-green-fg">def</span> untilStreamIsReady<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">,</span> progressions<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">3</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    100</span>   <span class="ansi-green-fg">import</span> time
# <span class="ansi-green-fg">--&gt; 101</span><span class="ansi-red-fg">   </span>queries <span class="ansi-blue-fg">=</span> list<span class="ansi-blue-fg">(</span>filter<span class="ansi-blue-fg">(</span><span class="ansi-green-fg">lambda</span> query<span class="ansi-blue-fg">:</span> query<span class="ansi-blue-fg">.</span>name <span class="ansi-blue-fg">==</span> name <span class="ansi-green-fg">or</span> query<span class="ansi-blue-fg">.</span>name <span class="ansi-blue-fg">==</span> name <span class="ansi-blue-fg">+</span> <span class="ansi-blue-fg">&#34;_p&#34;</span><span class="ansi-blue-fg">,</span> getActiveStreams<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    102</span>
# <span class="ansi-green-intense-fg ansi-bold">    103</span>   <span class="ansi-green-fg">while</span> <span class="ansi-blue-fg">(</span>len<span class="ansi-blue-fg">(</span>queries<span class="ansi-blue-fg">)</span> <span class="ansi-blue-fg">==</span> <span class="ansi-cyan-fg">0</span> <span class="ansi-green-fg">or</span> len<span class="ansi-blue-fg">(</span>queries<span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>recentProgress<span class="ansi-blue-fg">)</span> <span class="ansi-blue-fg">&lt;</span> progressions<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/functions.py</span> in <span class="ansi-cyan-fg">filter</span><span class="ansi-blue-fg">(col, f)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4367</span>     <span class="ansi-blue-fg">+</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">+</span>
# <span class="ansi-green-intense-fg ansi-bold">   4368</span>     &#34;&#34;&#34;
# <span class="ansi-green-fg">-&gt; 4369</span><span class="ansi-red-fg">     </span><span class="ansi-green-fg">return</span> _invoke_higher_order_function<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;ArrayFilter&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">[</span>col<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">[</span>f<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4370</span>
# <span class="ansi-green-intense-fg ansi-bold">   4371</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/functions.py</span> in <span class="ansi-cyan-fg">_invoke_higher_order_function</span><span class="ansi-blue-fg">(name, cols, funs)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4197</span>     expr <span class="ansi-blue-fg">=</span> getattr<span class="ansi-blue-fg">(</span>expressions<span class="ansi-blue-fg">,</span> name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4198</span>
# <span class="ansi-green-fg">-&gt; 4199</span><span class="ansi-red-fg">     </span>jcols <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span>_to_java_column<span class="ansi-blue-fg">(</span>col<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>expr<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">for</span> col <span class="ansi-green-fg">in</span> cols<span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">   4200</span>     jfuns <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span>_create_lambda<span class="ansi-blue-fg">(</span>f<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">for</span> f <span class="ansi-green-fg">in</span> funs<span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">   4201</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/functions.py</span> in <span class="ansi-cyan-fg">&lt;listcomp&gt;</span><span class="ansi-blue-fg">(.0)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4197</span>     expr <span class="ansi-blue-fg">=</span> getattr<span class="ansi-blue-fg">(</spa

# %% [markdown]
# ### 4. Monitor streaming query
# - Get ID of streaming query
# - Get status of streaming query

# %%
queryID = couponSalesQuery.id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
queryStatus = couponSalesQuery.status
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
# ##### <img alt="Best Practice" title="Best Practice" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-blue-ribbon.svg"/> Check your work

# %%
assert type(queryID) == str
assert list(queryStatus.keys()) == ['message', 'isDataAvailable', 'isTriggerActive']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### 5. Stop streaming query
# - Stop the streaming query

# %%
couponSalesQuery.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
# ##### <img alt="Best Practice" title="Best Practice" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-blue-ribbon.svg"/> Check your work

# %%
assert not couponSalesQuery.isActive
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Classroom Cleanup
# Run the cell below to clean up resources.

# %%
# %run ./Includes/Classroom-Cleanup
# Out:
# Dropped database and removed files in working directory

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
