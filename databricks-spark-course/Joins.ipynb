# %% [markdown]
# d-sandbox
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 400px">
# </div>

# %% [markdown]
# # ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Abandoned Carts Lab
# Get abandoned cart items for email without purchases.
# 1. Get emails of converted users from transactions
# 2. Join emails with user IDs
# 3. Get cart item history for each user
# 4. Join cart item history with emails
# 5. Filter for emails with abandoned cart items
#
# ##### Methods
# - DataFrame (<a href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=dataframe#pyspark.sql.DataFrame" target="_blank">Python</a>/<a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/Dataset.html" target="_blank">Scala</a>): `join`
# - Built-In Functions (<a href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=functions#module-pyspark.sql.functions" target="_blank">Python</a>/<a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/functions$.html" target="_blank">Scala</a>): `lit`
# - DataFrameNaFunctions (<a href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=nafunctions#pyspark.sql.DataFrameNaFunctions" target="_blank">Python</a>/<a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/DataFrameNaFunctions.html" target="_blank">Scala</a>): `fill`

# %% [markdown]
# ### Setup
# Run the cells below to create DataFrames **`salesDF`**, **`usersDF`**, and **`eventsDF`**.

# %%
# %run ./Includes/Classroom-Setup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Datasets mounted and student environment set up

# %%
# sale transactions at BedBricks
salesDF = spark.read.parquet(salesPath)
display(salesDF.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>email</th><th>transaction_timestamp</th><th>total_item_quantity</th><th>purchase_revenue_in_usd</th><th>unique_items</th><th>items</th></tr></thead><tbody><tr><td>257437</td><td>kmunoz@powell-duran.com</td><td>1592194221828900</td><td>1</td><td>1995.0</td><td>1</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td></tr><tr><td>282611</td><td>bmurillo@hotmail.com</td><td>1592504237604072</td><td>1</td><td>940.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1))</td></tr><tr><td>257448</td><td>bradley74@gmail.com</td><td>1592200438030141</td><td>1</td><td>945.0</td><td>1</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td></tr><tr><td>257440</td><td>jameshardin@campbell-morris.biz</td><td>1592197217716495</td><td>1</td><td>1045.0</td><td>1</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td></tr><tr><td>283949</td><td>whardin@hotmail.com</td><td>1592510720760323</td><td>1</td><td>535.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1))</td></tr></tbody></table></div>

# %%
# user IDs and emails at BedBricks
usersDF = spark.read.parquet(usersPath)
display(usersDF.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>user_first_touch_timestamp</th><th>email</th></tr></thead><tbody><tr><td>UA000000102357305</td><td>1592182691348767</td><td>null</td></tr><tr><td>UA000000102357308</td><td>1592183287634953</td><td>null</td></tr><tr><td>UA000000102357309</td><td>1592183302736627</td><td>null</td></tr><tr><td>UA000000102357321</td><td>1592184604178702</td><td>david23@orozco-parker.com</td></tr><tr><td>UA000000102357325</td><td>1592185154063628</td><td>null</td></tr></tbody></table></div>

# %%
print(f"The number of recorded users: {usersDF.count()}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The number of recorded users: 5025947
# </div>

# %%
# events logged on the BedBricks website
eventsDF = spark.read.parquet(eventsPath)
display(eventsDF.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device</th><th>ecommerce</th><th>event_name</th><th>event_previous_timestamp</th><th>event_timestamp</th><th>geo</th><th>items</th><th>traffic_source</th><th>user_first_touch_timestamp</th><th>user_id</th></tr></thead><tbody><tr><td>macOS</td><td>List(null, null, null)</td><td>warranty</td><td>1593878899217692</td><td>1593878946592107</td><td>List(Montrose, MI)</td><td>List()</td><td>google</td><td>1593878899217692</td><td>UA000000107379500</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>press</td><td>1593876662175340</td><td>1593877011756535</td><td>List(Northampton, MA)</td><td>List()</td><td>google</td><td>1593876662175340</td><td>UA000000107359357</td></tr><tr><td>macOS</td><td>List(null, null, null)</td><td>add_item</td><td>1593878792892652</td><td>1593878815459100</td><td>List(Salinas, CA)</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td><td>youtube</td><td>1593878455472030</td><td>UA000000107375547</td></tr><tr><td>iOS</td><td>List(null, null, null)</td><td>mattresses</td><td>1593878178791663</td><td>1593878809276923</td><td>List(Everett, MA)</td><td>List()</td><td>facebook</td><td>1593877903116176</td><td>UA000000107370581</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>mattresses</td><td>null</td><td>1593878628143633</td><td>List(Cottage Grove, MN)</td><td>List()</td><td>google</td><td>1593878628143633</td><td>UA000000107377108</td></tr></tbody></table></div>

# %% [markdown]
# ### 1. Get emails of converted users from transactions
# - Select **`email`** column in **`salesDF`** and remove duplicates
# - Add new column **`converted`** with value **`True`** for all rows
#
# Save result as **`convertedUsersDF`**.

# %%
from pyspark.sql.functions import *
convertedUsersDF = (salesDF.select("Email")
                    .dropDuplicates()
                    .withColumn('converted', lit(True))
)
display(convertedUsersDF.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Email</th><th>converted</th></tr></thead><tbody><tr><td>zacharyfisher@brown.com</td><td>true</td></tr><tr><td>flowersrhonda@paul.com</td><td>true</td></tr><tr><td>tanya8857@yahoo.com</td><td>true</td></tr><tr><td>serranoerika@brooks-lawson.com</td><td>true</td></tr><tr><td>bishopamber@yahoo.com</td><td>true</td></tr></tbody></table></div>

# %%
print(f"The number of unique emails of recorded users that make purchases: {convertedUsersDF.count()}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The number of unique emails of recorded users that make purchases: 210370
# </div>

# %% [markdown]
# ### 2. Join emails with user IDs
# - Perform an outer join on **`convertedUsersDF`** and **`usersDF`** with the **`email`** field
# - Filter for users where **`email`** is not null
# - Fill null values in **`converted`** as **`False`**
#
# Save result as **`conversionsDF`**.

# %%
# TODO
conversionsDF = (usersDF.join(convertedUsersDF, on=["email"], how="full_outer")
                 .filter(col("email").isNotNull())
)
conversionsDF = conversionsDF.fillna(False, subset=['converted'])
display(conversionsDF.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>user_id</th><th>user_first_touch_timestamp</th><th>converted</th></tr></thead><tbody><tr><td>aacevedo@moss-young.com</td><td>UA000000103755561</td><td>1592671212475050</td><td>false</td></tr><tr><td>aacosta11@gmail.com</td><td>UA000000106362980</td><td>1593540790039008</td><td>false</td></tr><tr><td>aadams9@gmail.com</td><td>UA000000103384927</td><td>1592575968245258</td><td>false</td></tr><tr><td>aadams@coleman.org</td><td>UA000000107105749</td><td>1593795399348718</td><td>false</td></tr><tr><td>aadams@howard.biz</td><td>UA000000104562958</td><td>1592928837244180</td><td>false</td></tr></tbody></table></div>

# %%
print("The number of rows in conversionsDF: {}".format(conversionsDF.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The number of rows in conversionsDF: 782749
# </div>

# %%
print("The number of unique emails in conversionsDF: {}".format(conversionsDF.select("email").dropDuplicates().count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The number of unique emails in conversionsDF: 782749
# </div>

# %% [markdown]
# ### 3. Get cart item history for each user
# - Explode **`items`** field in **`eventsDF`**
# - Group by **`user_id`**
#   - Collect set of all **`items.item_id`** objects for each user and alias with "cart"
#
# Save result as **`cartsDF`**.

# %%
cartsDF = (eventsDF.withColumn("items", explode("items"))
           .groupBy("user_id")
           .agg(collect_set("items.item_id").alias("cart"))
)
display(cartsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>cart</th></tr></thead><tbody><tr><td>UA000000102360011</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102362166</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102368105</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102370324</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102371333</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102377152</td><td>List(M_STAN_F)</td></tr><tr><td>UA000000102386796</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102390929</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102398119</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102400606</td><td>List(M_PREM_Q)</td></tr><tr><td>UA000000102404659</td><td>List(M_STAN_F)</td></tr><tr><td>UA000000102405151</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102413081</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102415866</td><td>List(M_PREM_Q, M_STAN_F)</td></tr><tr><td>UA000000102418071</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102419569</td><td>List(M_PREM_K)</td></tr><tr><td>UA000000102421047</td><td>List(M_STAN_F)</td></tr><tr><td>UA000000102428990</td><td>List(P_FOAM_K)</td></tr><tr><td>UA000000102432204</td><td>List(M_PREM_T)</td></tr><tr><td>UA000000102432686</td><td>List(M_STAN_T, P_FOAM_K)</td></tr><tr><td>UA000000102434583</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102435453</td><td>List(P_FOAM_S, M_STAN_Q)</td></tr><tr><td>UA000000102437898</td><td>List(M_PREM_Q)</td></tr><tr><td>UA000000102440333</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102441051</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102443296</td><td>List(P_FOAM_S)</td></tr><tr><td>UA000000102444407</td><td>List(M_STAN_K, P_DOWN_K)</td></tr><tr><td>UA000000102445199</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102447700</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102449832</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102452891</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102454031</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102454481</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102456729</td><td>List(P_FOAM_S)</td></tr><tr><td>UA000000102457451</td><td>List(M_PREM_T)</td></tr><tr><td>UA000000102461260</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102462865</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102465396</td><td>List(M_PREM_F)</td></tr><tr><td>UA000000102469399</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102470089</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102472359</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102481593</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102483066</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102483475</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102484386</td><td>List(M_PREM_K)</td></tr><tr><td>UA000000102484507</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102491773</td><td>List(M_STAN_F)</td></tr><tr><td>UA000000102495929</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102496262</td><td>List(M_PREM_K)</td></tr><tr><td>UA000000102497918</td><td>List(M_PREM_Q)</td></tr><tr><td>UA000000102498849</td><td>List(M_STAN_F)</td></tr><tr><td>UA000000102498942</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102499992</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102504313</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102504956</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102507248</td><td>List(M_PREM_F)</td></tr><tr><td>UA000000102507984</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102508907</td><td>List(M_STAN_F)</td></tr><tr><td>UA000000102511943</td><td>List(M_PREM_F)</td></tr><tr><td>UA000000102513079</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102514350</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102514855</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102525768</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102529171</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102529781</td><td>List(M_PREM_Q)</td></tr><tr><td>UA000000102529919< ...

# %% [markdown]
# ### 4. Join cart item history with emails
# - Perform a left join on **`conversionsDF`** and **`cartsDF`** on the **`user_id`** field
#
# Save result as **`emailCartsDF`**.

# %%
# TODO
emailCartsDF = conversionsDF.join(cartsDF, on="user_id", how="left")
display(emailCartsDF.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>email</th><th>user_first_touch_timestamp</th><th>converted</th><th>cart</th></tr></thead><tbody><tr><td>UA000000102357285</td><td>ianortiz@francis.com</td><td>1592169133135185</td><td>false</td><td>null</td></tr><tr><td>UA000000102357324</td><td>mtorres@gmail.com</td><td>1592185107111059</td><td>false</td><td>null</td></tr><tr><td>UA000000102357753</td><td>kimberly84@strickland.biz</td><td>1592196381720379</td><td>false</td><td>null</td></tr><tr><td>UA000000102357771</td><td>nwilson2@yahoo.com</td><td>1592196573947350</td><td>false</td><td>null</td></tr><tr><td>UA000000102357938</td><td>choidaniel@price.com</td><td>1592198013565458</td><td>true</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ### 5. Filter for emails with abandoned cart items
# - Filter **`emailCartsDF`** for users where **`converted`** is False
# - Filter for users with non-null carts
#
# Save result as **`abandonedItemsDF`**.

# %%
# TODO
abandonedCartsDF = (emailCartsDF.filter(col('converted') == False)
                    .filter(col("cart").isNotNull())
)
display(abandonedCartsDF.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>email</th><th>user_first_touch_timestamp</th><th>converted</th><th>cart</th></tr></thead><tbody><tr><td>UA000000102386796</td><td>lukemiller@hotmail.com</td><td>1592221721420940</td><td>false</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102415866</td><td>klee@richardson-williams.net</td><td>1592228636702037</td><td>false</td><td>List(M_PREM_Q, M_STAN_F)</td></tr><tr><td>UA000000102454481</td><td>hdavis30@yahoo.com</td><td>1592235363612845</td><td>false</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102456729</td><td>lucaseric@yahoo.com</td><td>1592235717304674</td><td>false</td><td>List(P_FOAM_S)</td></tr><tr><td>UA000000102457451</td><td>rubiokatherine@yahoo.com</td><td>1592235835162487</td><td>false</td><td>List(M_PREM_T)</td></tr></tbody></table></div>

# %% [markdown]
# ### Bonus: Plot number of abandoned cart items by product

# %%
abandonedCartsDF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- user_id: string (nullable = true)
# -- email: string (nullable = true)
# -- user_first_touch_timestamp: long (nullable = true)
# -- converted: boolean (nullable = false)
# -- cart: array (nullable = true)
#     |-- element: string (containsNull = false)
#
# </div>

# %%
abandonedItemsDF = (abandonedCartsDF.select("cart")
        .withColumn("cart", explode("cart"))
        .groupBy("cart").count()
        .withColumnRenamed("count", "Number_of_abandoned_items")
        .sort("cart")
        .withColumnRenamed("cart", "Product")
)  
display(abandonedItemsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Product</th><th>Number_of_abandoned_items</th></tr></thead><tbody><tr><td>M_PREM_F</td><td>6363</td></tr><tr><td>M_PREM_K</td><td>9839</td></tr><tr><td>M_PREM_Q</td><td>11976</td></tr><tr><td>M_PREM_T</td><td>12527</td></tr><tr><td>M_STAN_F</td><td>25761</td></tr><tr><td>M_STAN_K</td><td>38765</td></tr><tr><td>M_STAN_Q</td><td>47008</td></tr><tr><td>M_STAN_T</td><td>50315</td></tr><tr><td>P_DOWN_K</td><td>2987</td></tr><tr><td>P_DOWN_S</td><td>6917</td></tr><tr><td>P_FOAM_K</td><td>5007</td></tr><tr><td>P_FOAM_S</td><td>11497</td></tr></tbody></table></div>

# %%
### Clean up classroom
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %run ./Includes/Classroom-Cleanup
# Out:
# Dropped database and removed files in working directory

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
